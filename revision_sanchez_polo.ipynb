# %% [markdown]
# ##### Autor: Andrés Rengifo J.

# %%
import pandas as pd
import os 
import numpy as np
from datetime import date

# %%
user= os.getlogin( )
root= "C:\\Users\\" +user+ "\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS"
empresas_folders= [f for f in os.listdir(root)] 
empresas_folders.pop(0)
empresas_folders.pop(0)
empresas_folders.pop(0)
empresas_folders
# Out:
# ['BOTERO SOTO (NOEL)(NUTRESA)',
#  'C&S LOGISTICA',
#  'CEMEX',
#  'CENTROLIMA',
#  'COLTANQUES',
#  'COTRANSCOL',
#  'DITRANSA',
#  'HDL - Bimbo',
#  'HDL - Colsubsidio',
#  'PLEXA',
#  'POSTOBON',
#  'RENTING COLOMBIA',
#  'SOLISTICA',
#  'TDH',
#  'TENARIS',
#  'TRANSPORTES SANCHEZ POLO (TSP)',
#  'Z. RESUMEN PLACAS']

# %%
#### folder llamado datos brutos
empresa_dir= os.path.join(root, empresas_folders[15])
data_folders= [f for f in os.listdir(empresa_dir) if "BRUTOS" in f] 
folder_brutos= os.path.join(empresa_dir, data_folders[0])
folder_brutos
# Out:
# 'C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\1. DATOS BRUTOS'

# %%
## carpetas que están dentro de la carpeta de datos brutos
br_folders= [f for f in os.listdir(folder_brutos)] 
br_folders[0]
br_folders= os.path.join(folder_brutos, br_folders[0] )
br_folders
###
# Out:
# 'C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\1. DATOS BRUTOS\\1. DATOS BRUTOS HASTA 11-05-2023'

# %%
data_folders= [f for f in os.listdir(br_folders) if '.rar' not in f] 
data_folders

raw_data_paths= []
for i in range(len(data_folders)):
    temp_path= os.path.join(br_folders, data_folders[i])
    temp_folder_list= [f for f in os.listdir(temp_path)] 
    for j in range(len(temp_folder_list)):
        raw_data_paths.append(os.path.join(temp_path, temp_folder_list[j]))
raw_data_paths
# Out:
# ['C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\1. DATOS BRUTOS\\1. DATOS BRUTOS HASTA 11-05-2023\\hcarboncsv\\hcarbon202201.csv',
#  'C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\1. DATOS BRUTOS\\1. DATOS BRUTOS HASTA 11-05-2023\\hcarboncsv\\hcarbon202202.csv',
#  'C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\1. DATOS BRUTOS\\1. DATOS BRUTOS HASTA 11-05-2023\\hcarboncsv\\hcarbon202203.csv',
#  'C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\1. DATOS BRUTOS\\1. DATOS BRUTOS HASTA 11-05-2023\\hcarboncsv\\hcarbon202204.csv',
#  'C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\1. DATOS BRUTOS\\1. DATOS BRUTOS HASTA 11-05-2023\\hcarboncsv\\hcarbon202209.csv',
#  'C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\1. DATOS BRUTOS\\1. DATOS BRUTOS HASTA 11-05-2023\\hcarboncsv\\hcarbon202210.csv',
#  'C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\1. DATOS BRUTOS\\1. DATOS BRUTOS HASTA 11-05-2023\\hcarboncsv\\hcarbon202211.csv',
#  'C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\1. DATOS BRUTOS\\1. DATOS BRUTOS HASTA 11-05-2023\\hcarboncsv\\hcarbon202212.csv',
#  'C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\1. DATOS BRUTOS\\1. DATOS BRUTOS HASTA 11-05-2023\\hcarboncsv\\hcarbon202301.csv']

# %%
temp_folder_list
# Out:
# ['hcarbon202201.csv',
#  'hcarbon202202.csv',
#  'hcarbon202203.csv',
#  'hcarbon202204.csv',
#  'hcarbon202209.csv',
#  'hcarbon202210.csv',
#  'hcarbon202211.csv',
#  'hcarbon202212.csv',
#  'hcarbon202301.csv']

# %%
df= pd.read_csv(raw_data_paths[11], delimiter= ";")
df.head()
# Out:
#          id  id_maestro estado  operador   placa  planilla  \
# 0  72479434    72479433             SPIA  UZN155  11067859
# 1  72479442    72479437         DETEKTOR  ETT466  10676002
# 2  72479443    72479439         DETEKTOR  LJZ599  11061632
# 3  72479444    72479440         DETEKTOR  SRM602  11070099
# 4  72479445    72479441         DETEKTOR  SZN867  11094452
#
#                                      observacion_gps tipo_evento  velocidad  \
# 0  Observacion :  - Ubicacion : CR 23 CL 10 CARTA...         OBS        0.0
# 1  Observacion : Por tiempo de lectura - Ubicacio...         OBS       -1.0
# 2  Observacion : Por tiempo de lectura - Ubicacio...         OBS       -1.0
# 3  Observacion : Por tiempo de lectura - Ubicacio...         OBS       -1.0
# 4  Observacion : Por tiempo de lectura - Ubicacio...         OBS       -1.0
#
#              fecha_gps                       ubicacion_desc codciu   latitud  \
# 0  2022-12-31 23:56:45  CR 23 CL 10 CARTAGO VALLE DEL CAUCA    NaN  4.731725
# 1  2023-01-01 00:02:00                  BOGOTA-CUNDINAMARCA   OY00  4.658062
# 2  2023-01-01 00:03:25               COLOMBIA-SOUTH AMERICA    NaN  0.823620
# 3  2023-01-01 00:04:23                   MEDELLIN-ANTIOQUIA   ME00  6.211704
# 4  2023-01-01 00:04:04                  BOGOTA-CUNDINAMARCA   OY00  4.638963
#
#     longitud               creation_date
# 0 -75.910361   2023-01-01 00:08:39.03802
# 1 -74.153321  2023-01-01 00:09:52.857421
# 2 -77.646901  2023-01-01 00:09:52.968864
# 3 -75.581045  2023-01-01 00:09:53.079875
# 4 -74.118152  2023-01-01 00:09:53.197939

# %%
##### 
lat_var='latitud'
lon_var= 'longitud'
placa_var= "placa"
velocidad_var= "velocidad"

x= 0  ### cuanta las iteraciones

for j in range(len(raw_data_paths)): 
    gps_temp= pd.read_csv(raw_data_paths[j], delimiter= ";" ) 

    ### registrar el nombre de las variables antes de introducir otras
    colums= ""
    for k in range(len(gps_temp.columns)):
      colums= colums + gps_temp.columns[k] + "," 
    ### velocidad
    velocity= gps_temp.groupby(placa_var)[[velocidad_var]].agg(['mean', 'min', 'max'])
    velocity.reset_index(inplace=True)
    colnames= [ f[0] +"_" + f[1]  for f in  velocity.columns]
    velocity.columns= colnames
    tem_varname= placa_var +"_"
    velocity.rename(columns={tem_varname: "PLACA"}, inplace= True)
    velocity['Rango Velocidad']= ""
    for t in range(len(velocity)):
        a=velocity.loc[t,  velocidad_var+'_min']
        b=velocity.loc[t, velocidad_var+'_max']
        velocity.loc[t, 'Rango Velocidad']= "("+ str(a) + "-" + str(b) + ")"
    
    velocity= velocity[['PLACA', velocidad_var+ '_mean', "Rango Velocidad" ]]

    gps_temp['velocidad_valida']= 1
    gps_temp.loc[gps_temp[velocidad_var]> 125, 'velocidad_valida']= 0
    gps_temp.loc[gps_temp[velocidad_var]< 0, 'velocidad_valida']= 0    ### velocidades menores a cero
    for var in [lat_var , lon_var]:
            varname= var + "_valida"
            gps_temp[varname]= 1
            if var== lon_var:
                    gps_temp.loc[abs(gps_temp[var])> 180, 'velocidad_valida']= 0
            elif var== lat_var:
                    gps_temp.loc[abs(gps_temp[var])> 90, 'velocidad_valida']= 0

    gps_temp['obs_valida']= 1

    lat_valida=  lat_var + "_valida"
    lon_valida=  lon_var + "_valida"

    gps_temp.loc[(gps_temp['velocidad_valida']== 0) | (gps_temp[lat_valida]== 0) | (gps_temp[lon_valida]== 0), 'obs_valida']= 0

    obs_validas= gps_temp.groupby(placa_var)[['obs_valida']].agg(['mean', "sum"])
    obs_validas.reset_index(inplace=True)
    obs_validas.columns= ["PLACA", "obs_validas (%)", "obs_validas total"]

    regis=gps_temp.groupby(placa_var)[[placa_var]].agg('count')
    regis.columns= ["CANT.REGISTROS"]
    regis.reset_index(inplace=True)
      
    ### latitud longitud
    t=0
    for var in [lat_var , lon_var]:
          tem_data=  gps_temp.groupby(placa_var)[[var]].agg(['min', 'max'])
          tem_data.columns= tem_data.columns.droplevel()
          tem_data.reset_index(inplace=True)
          col_min= var + '_min'
          col_max= var + '_max'
          tem_data.columns= [placa_var,col_min , col_max]
          if t==0:
            lat_lon=tem_data.copy()
          else: 
                lat_lon= pd.merge(lat_lon, tem_data, on= placa_var) 
          t= t+1
    lat_lon['Rango Longitud']= ""
    lat_lon['Rango Latitud']= ""
    for p in range(len(lat_lon)):
          for var in [lat_var , lon_var]:
                col_min= var + '_min'
                col_max= var + '_max'
                a=lat_lon.loc[p, col_min]
                b=lat_lon.loc[p, col_max]
                if var== lon_var:
                      lat_lon.loc[p, 'Rango Longitud']= "("+ str(a) + "," + str(b) + ")"
                elif var== lat_var:
                      lat_lon.loc[p, 'Rango Latitud']= "("+ str(a) + "," + str(b) + ")"

    tem_revision_data= pd.merge(lat_lon[[placa_var, "Rango Longitud", "Rango Latitud" ]], regis, on= placa_var )
    ### Fecha
    today = date.today()
    tem_revision_data["Fecha Revisión"]= today
    ### id
    a= len(tem_revision_data)+ 1
    tem_revision_data["ID Archivo-Placa"]= range(1, a)
    ### nombre archivo-pestaña
    tem_revision_data["Nombre Archivo-Pestaña"]=  temp_folder_list[j] 
    # PLACA
    tem_revision_data = tem_revision_data.rename(columns={placa_var: 'PLACA'})

    tem_revision_data=pd.merge(tem_revision_data, velocity, on= "PLACA", how= "outer")
    tem_revision_data=pd.merge(tem_revision_data, obs_validas, on= "PLACA", how= "outer")
    #### Nombre de Variables

    tem_revision_data["Nombre Variables"]=  colums
    if x==0: 
        revision_data=  tem_revision_data.copy()
    else :
        revision_data= revision_data.append(tem_revision_data)   
    x=x+1

# %%
first_vars = ['ID Archivo-Placa', 'PLACA', 'Nombre Archivo-Pestaña', 'Fecha Revisión']   ## variables que queremos de primeras
varlist =[w for w in revision_data.columns if w not in first_vars]
order_var= first_vars+varlist
order_var
# Out:
# ['ID Archivo-Placa',
#  'PLACA',
#  'Nombre Archivo-Pestaña',
#  'Fecha Revisión',
#  'Rango Longitud',
#  'Rango Latitud',
#  'CANT.REGISTROS',
#  'velocidad_mean',
#  'Rango Velocidad',
#  'obs_validas (%)',
#  'obs_validas total',
#  'Nombre Variables']

# %%
### sort variables
#order_var= ['ID Archivo-Placa', 'PLACA', 'Nombre Archivo-Pestaña', 'Fecha Revisión', 'Rango Longitud', 'Rango Latitud', 'CANT.REGISTROS',
#          'velocidad_mean', 'Rango Velocidad', 'obs_validas (%)',
#          'obs_validas total', 'Nombre Variables'  ]

revision_data= revision_data[order_var]

# %%
revision_data
# Out:
#      ID Archivo-Placa    PLACA Nombre Archivo-Pestaña Fecha Revisión  \
# 0                   1  A44BO2G      hcarbon202201.csv     2023-05-22
# 1                   2   AHA982      hcarbon202201.csv     2023-05-22
# 2                   3   ATI739      hcarbon202201.csv     2023-05-22
# 3                   4   BUJ058      hcarbon202201.csv     2023-05-22
# 4                   5   CAF397      hcarbon202201.csv     2023-05-22
# ..                ...      ...                    ...            ...
# 664               665   ZNL024      hcarbon202301.csv     2023-05-22
# 665               666   ZNL071      hcarbon202301.csv     2023-05-22
# 666               667   ZNL074      hcarbon202301.csv     2023-05-22
# 667               668   ZNL096      hcarbon202301.csv     2023-05-22
# 668               669   ZNL531      hcarbon202301.csv     2023-05-22
#
#               Rango Longitud          Rango Latitud  CANT.REGISTROS  \
# 0    (-74.854987,-72.066301)  (10.835431,11.545761)             254
# 1       (-74.8577,-74.76517)     (10.83101,11.0024)             262
# 2      (-74.87874,-74.76821)     (10.85257,11.0375)             140
# 3       (-74.8827,-74.77215)    (10.88235,11.03878)             611
# 4      (-76.96793,-73.39943)     (3.76807,10.98058)            1406
# ..                       ...                    ...             ...
# 664  (-76.511925,-75.209732)   (3.466112,10.387625)              78
# 665  (-76.509284,-75.202862)    (3.460912,10.40145)             475
# 666    (-76.50799,-73.16349)     (3.49541,11.01379)             330
# 667     (-76.50168,-75.2036)     (3.53648,10.30891)             211
# 668  (-76.731073,-75.569793)    (3.538462,8.093456)             355
#
#      velocidad_mean Rango Velocidad  obs_validas (%)  obs_validas total  \
# 0         17.161417      (0.0-73.0)              1.0                254
# 1          6.129771      (0.0-43.0)              1.0                262
# 2          3.964286      (0.0-55.0)              1.0                140
# 3          2.869067      (0.0-43.0)              1.0                611
# 4         15.713371      (0.0-89.0)              1.0               1406
# ..              ...             ...              ...                ...
# 664       -1.000000     (-1.0--1.0)              0.0                  0
# 665       -1.000000     (-1.0--1.0)              0.0                  0
# 666       22.581818      (0.0-77.0)              1.0                330
# 667       20.208531      (0.0-74.0)              1.0                211
# 668       -1.000000     (-1.0--1.0)              0.0                  0
#
#                                       Nombre Variables
# 0    id,id_maestro,estado,operador,placa,planilla,o...
# 1    id,id_maestro,estado,operador,placa,planilla,o...
# 2    id,id_maestro,estado,operador,placa,planilla,o...
# 3    id,id_maestro,estado,operador,placa,planilla,o...
# 4    id,id_maestro,estado,operador,placa,planilla,o...
# ..                                                 ...
# 664  id,id_maestro,estado,operador,placa,planilla,o...
# 665  id,id_maestro,estado,operador,placa,planilla,o...
# 666  id,id_maestro,estado,operador,placa,planilla,o...
# 667  id,id_maestro,estado,operador,placa,planilla,o...
# 668  id,id_maestro,estado,operador,placa,planilla,o...
#
# [8371 rows x 12 columns]

# %% [markdown]
# #### Agregados

# %%
#### Agregados
agregado= pd.DataFrame( columns= [ 'TOTAL ARCHIVOS/BD',  'ARCHIVOS/BD CORRECTOS', 'TOTAL VEHÍCULOS' , 'TOTAL VEHÍCULOS CORRECTOS',	 'TOTAL REGISTROS',	'TOTAL REGISTROS CORRECTOS', 'PORCENTAGE REGISTROS CORRECTOS' ])

### total archivos
agregado.loc[1, 'TOTAL ARCHIVOS/BD' ]= len(raw_data_paths)

# total vehículos

a= len(revision_data.groupby("PLACA")[["PLACA"]].agg("count"))
agregado.loc[1, 'TOTAL VEHÍCULOS' ]= a

# archivos correctos
agregado.loc[1, 'ARCHIVOS/BD CORRECTOS' ]= len(raw_data_paths)

### perdimos vehículos con observaciones correctas= 0
dummy_df= revision_data.groupby("PLACA")[["obs_validas total"]].agg("sum")
dummy_df.reset_index(inplace=True)
dummy_df["dummy_var"]= 1
dummy_df.loc[dummy_df["obs_validas total"]==0 , "dummy_var"]= 0

a= dummy_df["dummy_var"].sum()

# Total vehículos correctos
agregado.loc[1, 'TOTAL VEHÍCULOS CORRECTOS' ]= a

## total registros
a= revision_data['CANT.REGISTROS'].sum()
agregado.loc[1, 'TOTAL REGISTROS' ]= a

### total registrs válidos

a= revision_data['obs_validas total'].sum()
agregado.loc[1, 'TOTAL REGISTROS CORRECTOS' ]= a

agregado.loc[1, 'PORCENTAGE REGISTROS CORRECTOS' ]= agregado.loc[1, 'TOTAL REGISTROS CORRECTOS' ]/agregado.loc[1, 'TOTAL REGISTROS' ]

# %%
out_folders_1= [f for f in os.listdir(empresa_dir) if "REVISADOS" in f] 
temp_path= os.path.join(empresa_dir, out_folders_1[0])
out_folders_2=  [f for f in os.listdir(temp_path) if "PLACAS" in f]  
temp_path= os.path.join(temp_path,out_folders_2[0] )
file_name= empresas_folders[15] + " TRAZABILIDAD_code.xlsx"
out_file=  os.path.join(temp_path, file_name) 

writer = pd.ExcelWriter(out_file, engine="xlsxwriter")
revision_data.to_excel(writer, index=False, sheet_name= "desagregado")
agregado.to_excel(writer, index=False, sheet_name= "agregado")

writer.close()
out_file
# Out:
# 'C:\\Users\\Andres Felipe\\Universidad de los Andes\\UK PACT- Giro Zero - GiroZero GPS - GiroZero GPS\\TRANSPORTES SANCHEZ POLO (TSP)\\2. DATOS REVISADOS\\1. INFORMACION PLACAS\\TRANSPORTES SANCHEZ POLO (TSP) TRAZABILIDAD_code.xlsx'

# %%
###  coltanques
